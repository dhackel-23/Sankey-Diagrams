# %%
#IMPORTS 
import pandas as pd
from floweaver import *
from mip import *
from functools import cmp_to_key
from attr import evolve
import statistics
import time
from ipysankeywidget import SankeyWidget
from ipywidgets import Layout, Output

# %%
# Load with Dataset.from_csv
dataset = Dataset.from_csv("test_flows.csv", "test_processes.csv")

# %%
# Creating the partitions for the processes
partition_farms = Partition.Simple('process', ['farm1', 'farm2', 'farm3'])
partition_eat = Partition.Simple('process', ['domestic', 'industry'])
partition_dest = Partition.Simple('process', ['compost', 'landfill'])
partition_fruit = Partition.Simple('material', ['apples', 'bananas', 'oranges'])

# %%
# Defining the nodes, ordering and bundles 
nodes = {
    'farms':    ProcessGroup('function == "farms"', partition=partition_farms, title='Farms'),
    'eat':      ProcessGroup('function == "consumers"', partition=partition_eat, title='Eat'),
    'end':      ProcessGroup('function == "destination"', partition=partition_dest, title='Destination'),
    'fruit':    Waypoint(partition_fruit, title='fruit type')
}

ordering = [
    [[], ['farms'], []],
    [[], ['fruit'], []],
    [[], ['eat'], []],
    [[], ['end'], []],
]

bundles = [
    Bundle('farms', 'eat', waypoints=['fruit']),
    Bundle('eat', 'end'),
    Bundle('farms', Elsewhere),
    Bundle('eat', Elsewhere),
    Bundle(Elsewhere,'eat'),
    Bundle(Elsewhere,'end'),
]

# Color palette
palette = {
    'oranges': 'orange',
    'bananas': 'yellow',
    'apples': 'green',
    '*': 'lightblue'
}

# %%
# 1. Create the SankeyDefinition
sdd = SankeyDefinition(nodes, bundles, ordering, flow_partition=dataset.partition('material'))

# 2. Generate SankeyData (no optimisation)
sankey_data = weave(sdd, dataset, palette=palette)

# 3. Plot
sankey_data.to_widget(width=700, height=450, margins=dict(left=70, right=90))
# Out:
# SankeyWidget(groups=[{'id': 'farms', 'type': 'process', 'title': 'Farms', 'nodes': ['farms^farm1', 'farms^farm…

# %%
# Plotting new dataset optimised node ordering sankey diagram


sankey_data_evolved = optimise_node_order(sankey_data, group_nodes=True)
sankey_data_evolved.to_widget(width=700, height=450, margins=dict(left=100, right=120), debugging=True)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 36 (-24) rows, 24 (-28) columns and 108 (-56) elements
# Clp1000I sum of infeasibilities 1.53309e-08 - average 4.25859e-10, 16 fixed columns
# Coin0506I Presolve 20 (-16) rows, 8 (-16) columns and 44 (-64) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 36 rows, 24 columns (24 integer (24 of which binary)) and 108 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.041%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 8 integers unsatisfied sum - 4
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 13
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of 2.70009
# Cbc0038I Reduced cost fixing fixed 14 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.94987 (10) obj. 2.70009 iterations 7
# Cbc0038I Pass   3: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass   4: suminf.    1.94987 (10) obj. 2.70009 iterations 8
# Cbc0038I Pass   5: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass   6: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass   7: suminf.    1.94987 (10) obj. 2.70009 iterations 2
# Cbc0038I Pass   8: suminf.    2.94986 (9) obj. 2.70009 iterations 5
# Cbc0038I Pass   9: suminf.    1.94986 (10) obj. 2.70009 iterations 3
# Cbc0038I Pass  10: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  11: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass  12: suminf.    1.94986 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  13: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass  14: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  15: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  16: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  17: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  18: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  19: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  20: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  21: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  22: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  23: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  24: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  25: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  26: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  27: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  28: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  29: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  31: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of 4 - took 0.02 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 14 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.07
#
# 0.07981204986572266
# VBox(children=(SankeyWidget(groups=[{'id': 'farms', 'type': 'process', 'title': 'Farms', 'nodes': ['farms^farm…

# %%
sankey_data_evolved.to_widget(layout=optimise_node_positions(sankey_data_evolved, scale = 10,minimum_gap=10, margins=dict(left=100, right=120)), width=700, height=450)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 47 (-11) rows, 33 (-11) columns and 156 (-16) elements
# Clp1000I sum of infeasibilities 4.91589e-05 - average 1.04593e-06, 16 fixed columns
# Coin0506I Presolve 47 (0) rows, 17 (-16) columns and 120 (-36) elements
# Clp0006I 0  Obj 81338.666 Primal inf 5.6475742e-06 (13) Dual inf 9.4443189e+12 (15)
# Clp0029I End of values pass after 17 iterations
# Clp0014I Perturbing problem by 0.001% of 27.409533 - largest nonzero change 0.00025901779 ( 0.00069123247%) - largest zero change 2.7080466e-05
# Clp0000I Optimal - objective value 81338.695
# Clp0000I Optimal - objective value 81338.695
# Coin0511I After Postsolve, objective 81338.695, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 81338.695 Dual inf 7619.4803 (2)
# Clp0014I Perturbing problem by 0.001% of 17.533277 - largest nonzero change 0.00017573957 ( 0.00071648365%) - largest zero change 2.7080466e-05
# Clp0000I Optimal - objective value 81338.695
# Clp0000I Optimal - objective value 81338.695
# Clp0000I Optimal - objective value 81338.695
# Coin0511I After Postsolve, objective 81338.695, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 81338.69488 - 0 iterations time 0.012, Presolve 0.00, Idiot 0.01
#
# Starting MIP optimization
# Cgl0004I processed model has 48 rows, 33 columns (11 integer (11 of which binary)) and 151 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.498%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.45455
# Cbc0038I Pass   1: suminf.    1.00000 (5) obj. 192028 iterations 17
# Cbc0038I Solution found of 519904
# Cbc0038I Relaxing continuous gives 471904
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 10 continuous
# Cbc0038I Full problem 48 rows 33 columns, reduced to 19 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from 471904 to 182623 (0.01 seconds)
# Cbc0038I Round again with cutoff of 172494
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.27273 (5) obj. 172494 iterations 15
# Cbc0038I Pass   3: suminf.    0.47273 (1) obj. 172494 iterations 14
# Cbc0038I Pass   4: suminf.    0.09091 (1) obj. 172494 iterations 8
# Cbc0038I Pass   5: suminf.    0.18876 (1) obj. 172494 iterations 3
# Cbc0038I Pass   6: suminf.    0.84846 (4) obj. 172494 iterations 7
# Cbc0038I Pass   7: suminf.    0.72727 (3) obj. 172494 iterations 3
# Cbc0038I Pass   8: suminf.    1.00000 (3) obj. 172494 iterations 4
# Cbc0038I Pass   9: suminf.    0.40476 (1) obj. 172494 iterations 8
# Cbc0038I Pass  10: suminf.    0.09091 (1) obj. 172494 iterations 2
# Cbc0038I Pass  11: suminf.    0.27273 (2) obj. 172494 iterations 3
# Cbc0038I Pass  12: suminf.    0.18876 (1) obj. 172494 iterations 4
# Cbc0038I Pass  13: suminf.    0.09091 (1) obj. 172494 iterations 2
# Cbc0038I Pass  14: suminf.    0.28640 (2) obj. 172494 iterations 4
# Cbc0038I Pass  15: suminf.    0.09091 (1) obj. 172494 iterations 4
# Cbc0038I Pass  16: suminf.    0.09091 (1) obj. 172494 iterations 1
# Cbc0038I Pass  17: suminf.    0.40476 (1) obj. 172494 iterations 2
# Cbc0038I Pass  18: suminf.    0.09091 (1) obj. 172494 iterations 2
# Cbc0038I Pass  19: suminf.    0.47273 (1) obj. 172494 iterations 6
# Cbc0038I Pass  20: suminf.    0.09091 (1) obj. 172494 iterations 5
# Cbc0038I Pass  21: suminf.    0.18876 (1) obj. 172494 iterations 2
# Cbc0038I Pass  22: suminf.    0.54545 (3) obj. 172494 iterations 4
# Cbc0038I Pass  23: suminf.    0.18586 (2) obj. 172494 iterations 4
# Cbc0038I Pass  24: suminf.    0.18586 (2) obj. 172494 iterations 1
# Cbc0038I Pass  25: suminf.    0.47273 (1) obj. 172494 iterations 3
# Cbc0038I Pass  26: suminf.    0.09091 (1) obj. 172494 iterations 7
# Cbc0038I Pass  27: suminf.    0.18876 (1) obj. 172494 iterations 2
# Cbc0038I Pass  28: suminf.    0.47273 (1) obj. 172494 iterations 4
# Cbc0038I Pass  29: suminf.    0.49176 (2) obj. 172494 iterations 5
# Cbc0038I Pass  30: suminf.    0.09091 (1) obj. 172494 iterations 7
# Cbc0038I Pass  31: suminf.    0.40476 (1) obj. 172494 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 5 continuous
# Cbc0038I Full problem 48 rows 33 columns, reduced to 33 rows 22 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 182623 - took 0.02 seconds
# Cbc0012I Integer solution of 182622.67 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 48 rows 33 columns, reduced to 48 rows 26 columns
# Cbc0031I 6 added rows had average density of 4
# Cbc0013I At root node, 9 cuts changed objective from 81338.695 to 182622.67 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 3 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 9 row cuts average 3.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 182622.6653517868, took 11 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# 0.06351518630981445
# SankeyWidget(groups=[{'id': 'farms', 'type': 'process', 'title': 'Farms', 'nodes': ['farms^farm1', 'farms^farm…

# %%
# 1. Create the SankeyDefinition

new_flows = dataset._flows.copy()
i_delete = 5
row1 = new_flows.iloc[i_delete].copy()
row1.update({'source': 'HIDDEN'})
row2 = new_flows.iloc[i_delete].copy()
row2.update({'target': 'HIDDEN'})
new_flows = pd.concat([
    new_flows.iloc[:i_delete],
    new_flows.iloc[i_delete + 1:],
    pd.DataFrame([row1, row2]),
], ignore_index=True)
#new_flows.loc[new_flows.source == 'eat1', 'source'] = 'HIDDEN'
#new_flows.loc[new_flows.target == 'eat1', 'target'] = 'HIDDEN'

new_dataset = Dataset(new_flows, dataset._dim_process, dataset._dim_material)
sdd = SankeyDefinition(nodes, bundles, ordering, flow_partition=new_dataset.partition('material'))

# 2. Generate SankeyData (no optimisation)
sankey_data = weave(sdd, new_dataset, palette=palette)

# 3. Plot
sankey_data.to_widget(width=700, height=450, margins=dict(left=70, right=90))
# Out:
# SankeyWidget(groups=[{'id': 'farms', 'type': 'process', 'title': 'Farms', 'nodes': ['farms^farm1', 'farms^farm…

# %%
def compute_crossing_score_from_dict(crossing_areas):
    crossing_count = len(crossing_areas)
    crossing_area = sum(crossing_areas.values())
    return {
        "crossing_count": crossing_count,              # ✅ renamed
        "crossing_area": crossing_area,                # ✅ renamed
        "crossing_score": crossing_count * crossing_area
    }

# %%
def compute_combined_vertical_score_final(flows_df, y_coords, sankey_definition):
    scores = []

    # Detect waypoint layers
    waypoint_groups = [key for key, val in sankey_definition.nodes.items() if "Waypoint" in str(type(val))]
    layers = sankey_definition.ordering.layers
    flat_ordering = [group[1][0] if group[1] else None for group in layers]

    # Identify waypoint structures (left → waypoint → right)
    waypoint_structures = {}
    for idx, node in enumerate(flat_ordering):
        if node in waypoint_groups and 0 < idx < len(flat_ordering) - 1:
            wp = node
            left = flat_ordering[idx - 1]
            right = flat_ordering[idx + 1]
            waypoint_structures[(left, right)] = wp

    # Build node-to-group mapping (e.g., farm3 → farms)
    node_to_group = {}
    for group_name, group_def in sankey_definition.nodes.items():
        if hasattr(group_def, "partition"):
            for subgroup in group_def.partition.groups:
                node_to_group[subgroup.label] = group_name

    for _, row in flows_df.iterrows():
        src = row["source"]
        tgt = row["target"]
        width = row["value"]
        material = row["material"]

        src_group = node_to_group.get(src, "")
        tgt_group = node_to_group.get(tgt, "")

        score = None
        span = None

        # Use material name as the waypoint node
        for (left, right), wp_group in waypoint_structures.items():
            if src_group == left and tgt_group == right:
                waypoint_node = material  # e.g., 'apples', 'bananas'
                if src in y_coords and tgt in y_coords and waypoint_node in y_coords:
                    dy1 = abs(y_coords[src] - y_coords[waypoint_node])
                    dy2 = abs(y_coords[waypoint_node] - y_coords[tgt])
                    score = (dy1 + dy2) / width if width > 0 else float("inf")
                    span = dy1 + dy2
                    break

        # Fallback to simple span
        if score is None and src in y_coords and tgt in y_coords:
            span = abs(y_coords[src] - y_coords[tgt])
            score = span / width if width > 0 else float("inf")

        if score is not None:
            scores.append({
                "source": src,
                "target": tgt,
                "material": material,
                "width": width,
                "span": span,
                "vertical_score": score
            })

    return pd.DataFrame(scores)

# %%
def normalize_scores(df, columns_to_normalize):
    """
    Normalize specified columns in a DataFrame using min-max scaling.

    Args:
        df (pd.DataFrame): DataFrame with raw scores.
        columns_to_normalize (list of str): Column names to normalize.

    Returns:
        pd.DataFrame: DataFrame with normalized columns added (suffix "_norm").
    """
    norm_df = df.copy()
    for col in columns_to_normalize:
        min_val = norm_df[col].min()
        max_val = norm_df[col].max()
        if max_val - min_val == 0:
            # Avoid divide-by-zero if all values are the same
            norm_df[f"{col}_norm"] = 0
        else:
            norm_df[f"{col}_norm"] = (norm_df[col] - min_val) / (max_val - min_val)
    return norm_df

# %%
def hide_flows_by_index(dataset, row_indices):
    
    # Step 1: Copy original flows table
    new_flows = dataset._flows.copy()
    rows_to_hide = new_flows.iloc[row_indices]

    # Step 2: Replace each flow with 2 hidden ones (source and target)
    hidden_rows = []
    for _, row in rows_to_hide.iterrows():
        row_source = row.copy()
        row_source["source"] = "HIDDEN"

        row_target = row.copy()
        row_target["target"] = "HIDDEN"

        hidden_rows.extend([row_source, row_target])

    # Step 3: Remove original and append hidden
    new_flows = pd.concat([
        new_flows.drop(index=row_indices),
        pd.DataFrame(hidden_rows)
    ], ignore_index=True)

    return new_flows

# %%
import random

def select_flows_by_width_band(flows_df, target_frac=0.25, tolerance=0.10):
    """
    Select a set of flows whose combined width falls within a target fraction ± tolerance.
    
    Parameters:
        flows_df (pd.DataFrame): The full flow DataFrame containing 'value' as width.
        target_frac (float): Desired percentage of total width to remove (e.g., 0.25 for 25%)
        tolerance (float): Percentage tolerance (e.g., 0.10 for ±10%)

    Returns:
        list: List of selected row indices to remove.
    """
    total_width = flows_df["value"].sum()
    min_width = total_width * (target_frac * (1 - tolerance))
    max_width = total_width * (target_frac * (1 + tolerance))
    
    remaining_indices = list(flows_df.index)
    random.shuffle(remaining_indices)

    selected = []
    current_sum = 0

    for idx in remaining_indices:
        flow_width = flows_df.loc[idx, "value"]
        if current_sum + flow_width > max_width:
            continue
        selected.append(idx)
        current_sum += flow_width
        if current_sum >= min_width:
            break

    return selected

# Example structure to confirm function works (we'll skip actually calling it here)
select_flows_by_width_band  # ready to integrate
# Out:
# <function __main__.select_flows_by_width_band(flows_df, target_frac=0.25, tolerance=0.1)>

# %%
from typing import Tuple

def update_results_table_with_full_metrics(
    dataset, sankey_definition, n_trials=10, removal_fraction=0.25, X1=1, X2=1
) -> Tuple[pd.DataFrame, dict, dict]:
    from floweaver import Dataset, weave
    from time import time

    results = []
    trial_details = {}

    original_width = dataset._flows["value"].sum()
    flow_df_full = dataset._flows.copy()

    # Compute original metrics
    sankey_original = weave(sankey_definition, dataset)
    sankey_orig_ordered, _, crossing_areas_orig = optimise_node_order(sankey_original, crossings__area=True)

    print("🧪 Node layers before layout:", sankey_orig_ordered.ordering.layers)

    # 🔧 FIX: Ensure minimum_gap is explicitly defined
    layout_orig = optimise_node_positions(sankey_orig_ordered, minimum_gap=20)

    y_coords_orig = {
        nid.split("^")[-1].split("*")[0]: pos[1]
        for nid, pos in layout_orig.node_positions.items()
    }

    vertical_df_orig = compute_combined_vertical_score_final(flow_df_full, y_coords_orig, sankey_definition)
    original_vertical_total = vertical_df_orig["vertical_score"].sum()

    crossing_metrics_orig = compute_crossing_score_from_dict(crossing_areas_orig)
    original_crossing_score = crossing_metrics_orig["crossing_score"]
    original_crossing_count = crossing_metrics_orig["crossing_count"]

    original_summary = {
        "original_crossings": int(original_crossing_count),
        "original_crossing_score": original_crossing_score,
        "original_vertical_score": original_vertical_total,
        "original_total_width": round(original_width, 2)
    }

    for trial in range(n_trials):
        start = time()

        selected_indices = select_flows_by_width_band(flow_df_full, removal_fraction)
        width_removed = flow_df_full.loc[selected_indices, "value"].sum()
        width_removed_pct = round(100 * width_removed / original_width, 2)

        modified_flows = hide_flows_by_index(dataset, selected_indices)
        new_dataset = Dataset(
            flows=modified_flows,
            dim_process=dataset._dim_process,
            dim_material=dataset._dim_material,
            dim_time=dataset._dim_time,
        )

        sankey_data = weave(sankey_definition, new_dataset)
        sankey_data_evolved, crossings, crossing_areas = optimise_node_order(
            sankey_data, crossings__area=True
        )
        ordered = optimise_node_order(sankey_data, group_nodes=True)

        # 🔧 FIX: Explicitly define minimum_gap
        layout = optimise_node_positions(ordered, minimum_gap=20)

        y_coords = {
            nid.split("^")[-1].split("*")[0]: pos[1]
            for nid, pos in layout.node_positions.items()
        }

        vertical_df = compute_combined_vertical_score_final(flow_df_full, y_coords, sankey_definition)
        vertical_df["flow_id"] = vertical_df.index
        vertical_total = vertical_df["vertical_score"].sum()

        crossing_metrics = compute_crossing_score_from_dict(crossing_areas)
        crossing_total = crossing_metrics["crossing_score"] // 2
        crossing_count = crossing_metrics["crossing_count"] // 2

        results.append({
            "trial": trial + 1,
            "crossing_count": crossing_count,
            "total_crossing_score": crossing_total,
            "total_vertical_score": vertical_total,
            "original_score": vertical_total + crossing_total,
            "total_width": round(original_width, 2),
            "width_removed": round(width_removed, 2),
            "width_removed_pct": width_removed_pct,
            "flow_count": len(flow_df_full),
            "flows_removed": list(selected_indices),
        })

        if trial < 3:
            trial_details[f"trial_{trial+1}"] = {
                "y_coords": y_coords,
                "vertical_table": vertical_df[[
                    "flow_id", "source", "target", "material", "width", "span", "vertical_score"
                ]],
                "crossing_metrics": crossing_metrics
            }

    results_df = pd.DataFrame(results)
    results_df["norm_vertical"] = (results_df["total_vertical_score"] - results_df["total_vertical_score"].min()) / (
        results_df["total_vertical_score"].max() - results_df["total_vertical_score"].min()
    )
    results_df["norm_crossing"] = (results_df["total_crossing_score"] - results_df["total_crossing_score"].min()) / (
        results_df["total_crossing_score"].max() - results_df["total_crossing_score"].min()
    )
    results_df["final_score"] = X1 * results_df["norm_vertical"] + X2 * results_df["norm_crossing"]

    summary = results_df.sort_values("final_score", ascending=True).reset_index(drop=True)

    return summary, trial_details, original_summary

# %%
summary_df, logs, original_metrics = update_results_table_with_full_metrics(
    dataset, sdd, n_trials=100, removal_fraction=0.3, X1=1, X2=1
)

# 🧾 Print original dataset metrics
print("\n📊 ORIGINAL DATASET METRICS:")
for key, val in original_metrics.items():
    print(f"{key}: {val}")

# 📊 Final Ranked Summary
print("\n📊 Final Ranked Summary:")
print(summary_df[[
    "trial", "final_score", "original_score", 
    "total_crossing_score", "total_vertical_score", 
    "crossing_count", "width_removed", "width_removed_pct", "flows_removed"
]])

# 📄 Top 3 Layouts (Row Format for Easy Copying)
print("\n📄 Top 3 Layouts Summary (Row Format):")
top3 = summary_df.head(3)
for i, row in top3.iterrows():
    print(
        f"Trial {row['trial']} | "
        f"Crossings: {row['crossing_count']} | "
        f"Area: {row['total_crossing_score']} | "
        f"Span: {row['total_vertical_score']} | "
        f"Width: {row['total_width']} | "
        f"Removed: {row['width_removed']} ({row['width_removed_pct']}%) | "
        f"Flows: {row['flows_removed']}"
    )
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 36 (-24) rows, 24 (-28) columns and 108 (-56) elements
# Clp1000I sum of infeasibilities 1.53309e-08 - average 4.25859e-10, 16 fixed columns
# Coin0506I Presolve 20 (-16) rows, 8 (-16) columns and 44 (-64) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 36 rows, 24 columns (24 integer (24 of which binary)) and 108 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.041%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 8 integers unsatisfied sum - 4
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 13
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 2.70009
# Cbc0038I Reduced cost fixing fixed 14 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.94987 (10) obj. 2.70009 iterations 7
# Cbc0038I Pass   3: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass   4: suminf.    1.94987 (10) obj. 2.70009 iterations 8
# Cbc0038I Pass   5: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass   6: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass   7: suminf.    1.94987 (10) obj. 2.70009 iterations 2
# Cbc0038I Pass   8: suminf.    2.94986 (9) obj. 2.70009 iterations 5
# Cbc0038I Pass   9: suminf.    1.94986 (10) obj. 2.70009 iterations 3
# Cbc0038I Pass  10: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  11: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass  12: suminf.    1.94986 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  13: suminf.    1.94987 (10) obj. 2.70009 iterations 9
# Cbc0038I Pass  14: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  15: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  16: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  17: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  18: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  19: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  20: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  21: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  22: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  23: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  24: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  25: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  26: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  27: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  28: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  29: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I Pass  31: suminf.    1.94987 (10) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of 4 - took 0.02 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0038I Full problem 36 rows 24 columns, reduced to 18 rows 9 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 14 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.05
#
# 0.05730414390563965
# 🧪 Node layers before layout: (((), ('farms^farm3', 'farms^farm1', 'farms^farm2'), ()), ((), ('fruit^oranges', 'fruit^apples', 'fruit^bananas'), ()), ((), ('eat^industry', 'eat^domestic'), ()), ((), ('end^compost', 'end^landfill'), ()))
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 47 (-11) rows, 33 (-11) columns and 156 (-16) elements
# Clp1000I sum of infeasibilities 1.07271e-05 - average 2.28236e-07, 9 fixed columns
# Coin0506I Presolve 47 (0) rows, 24 (-9) columns and 136 (-20) elements
# Clp0006I 0  Obj 696.72761 Dual inf 14305.616 (14)
# Clp0029I End of values pass after 24 iterations
# Clp0014I Perturbing problem by 0.001% of 6.9583901 - largest nonzero change 5.3500463e-05 ( 0.0013637621%) - largest zero change 2.9394864e-05
# Clp0000I Optimal - objective value 696.72696
# Clp0000I Optimal - objective value 696.72696
# Coin0511I After Postsolve, objective 696.72696, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 696.72696
# Clp0000I Optimal - objective value 696.72696
# Clp0000I Optimal - objective value 696.72696
# Clp0000I Optimal - objective value 696.72696
# Coin0511I After Postsolve, objective 696.72696, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 696.7269561 - 0 iterations time 0.012, Presolve 0.00, Idiot 0.01
#
# Starting MIP optimization
# Cgl0004I processed model has 48 rows, 33 columns (11 integer (11 of which binary)) and 151 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.498%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 1.12727
# Cbc0038I Pass   1: suminf.    0.79091 (5) obj. 809.131 iterations 13
# Cbc0038I Solution found of 1165.9
# Cbc0038I Relaxing continuous gives 1117.9
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 48 rows 33 columns, reduced to 12 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from 1117.9 to 791.623 (0.01 seconds)
# Cbc0038I Round again with cutoff of 782.133
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.81818 (5) obj. 782.133 iterations 10
# Cbc0038I Pass   3: suminf.    0.09875 (1) obj. 782.133 iterations 10
# Cbc0038I Pass   4: suminf.    0.09875 (1) obj. 782.133 iterations 0
# Cbc0038I Pass   5: suminf.    0.18182 (1) obj. 782.133 iterations 4
# Cbc0038I Pass   6: suminf.    0.38417 (2) obj. 782.133 iterations 4
# Cbc0038I Pass   7: suminf.    0.38182 (3) obj. 782.133 iterations 3
# Cbc0038I Pass   8: suminf.    0.31387 (2) obj. 782.133 iterations 1
# Cbc0038I Pass   9: suminf.    0.47937 (1) obj. 782.133 iterations 2
# Cbc0038I Pass  10: suminf.    0.18182 (2) obj. 782.133 iterations 4
# Cbc0038I Pass  11: suminf.    0.47937 (1) obj. 782.133 iterations 1
# Cbc0038I Pass  12: suminf.    0.81494 (2) obj. 782.133 iterations 1
# Cbc0038I Pass  13: suminf.    1.00244 (3) obj. 782.133 iterations 1
# Cbc0038I Pass  14: suminf.    1.00244 (3) obj. 782.133 iterations 0
# Cbc0038I Pass  15: suminf.    1.29676 (4) obj. 782.133 iterations 1
# Cbc0038I Pass  16: suminf.    0.92068 (4) obj. 782.133 iterations 2
# Cbc0038I Pass  17: suminf.    0.09875 (1) obj. 782.133 iterations 4
# Cbc0038I Pass  18: suminf.    0.09875 (1) obj. 782.133 iterations 0
# Cbc0038I Pass  19: suminf.    0.18182 (1) obj. 782.133 iterations 8
# Cbc0038I Pass  20: suminf.    0.38417 (2) obj. 782.133 iterations 7
# Cbc0038I Pass  21: suminf.    0.65239 (3) obj. 782.133 iterations 1
# Cbc0038I Pass  22: suminf.    0.40000 (2) obj. 782.133 iterations 4
# Cbc0038I Pass  23: suminf.    1.10926 (3) obj. 782.133 iterations 9
# Cbc0038I Pass  24: suminf.    0.18182 (2) obj. 782.133 iterations 6
# Cbc0038I Pass  25: suminf.    0.47937 (1) obj. 782.133 iterations 1
# Cbc0038I Pass  26: suminf.    0.18182 (2) obj. 782.133 iterations 4
# Cbc0038I Pass  27: suminf.    0.47937 (1) obj. 782.133 iterations 1
# Cbc0038I Pass  28: suminf.    0.47937 (1) obj. 782.133 iterations 0
# Cbc0038I Pass  29: suminf.    0.40000 (3) obj. 782.133 iterations 5
# Cbc0038I Pass  30: suminf.    0.40000 (3) obj. 782.133 iterations 0
# Cbc0038I Pass  31: suminf.    0.40000 (3) obj. 782.133 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 5 continuous
# Cbc0038I Full problem 48 rows 33 columns, reduced to 34 rows 21 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 791.623 - took 0.02 seconds
# Cbc0012I Integer solution of 791.62267 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 48 rows 33 columns, reduced to 48 rows 26 columns
# Cbc0031I 6 added rows had average density of 6
# Cbc0013I At root node, 15 cuts changed objective from 696.72696 to 791.62267 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 8 row cuts average 8.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 4 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 12 row cuts average 6.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 791.622665351787, took 7 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.05
#
# 0.0572659969329834
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 32 (-24) rows, 21 (-21) columns and 96 (-56) elements
# Clp1000I sum of infeasibilities 1.69975e-08 - average 5.31172e-10, 14 fixed columns
# Coin0506I Presolve 18 (-14) rows, 7 (-14) columns and 40 (-56) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 32 rows, 21 columns (21 integer (21 of which binary)) and 96 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.326%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 7 integers unsatisfied sum - 3.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 9
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 2.70009
# Cbc0038I Reduced cost fixing fixed 12 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.78738 (9) obj. 2.70009 iterations 4
# Cbc0038I Pass   3: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass   4: suminf.    1.78738 (9) obj. 2.70009 iterations 8
# Cbc0038I Pass   5: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass   6: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass   7: suminf.    2.62489 (8) obj. 2.70009 iterations 2
# Cbc0038I Pass   8: suminf.    1.78738 (9) obj. 2.70009 iterations 2
# Cbc0038I Pass   9: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  10: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  11: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  12: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  13: suminf.    3.50000 (7) obj. 0 iterations 2
# Cbc0038I Pass  14: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  15: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  16: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  17: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  18: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  19: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  20: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  21: suminf.    3.50000 (7) obj. 2 iterations 4
# Cbc0038I Pass  22: suminf.    1.78738 (9) obj. 2.70009 iterations 5
# Cbc0038I Pass  23: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  24: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  25: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  26: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  27: suminf.    2.62489 (8) obj. 2.70009 iterations 3
# Cbc0038I Pass  28: suminf.    1.78738 (9) obj. 2.70009 iterations 3
# Cbc0038I Pass  29: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  31: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of 4 - took 0.02 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.06
#
# 0.06463193893432617
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 32 (-24) rows, 21 (-21) columns and 96 (-56) elements
# Clp1000I sum of infeasibilities 1.69975e-08 - average 5.31172e-10, 14 fixed columns
# Coin0506I Presolve 18 (-14) rows, 7 (-14) columns and 40 (-56) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 32 rows, 21 columns (21 integer (21 of which binary)) and 96 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.326%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 7 integers unsatisfied sum - 3.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 9
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 2.70009
# Cbc0038I Reduced cost fixing fixed 12 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.78738 (9) obj. 2.70009 iterations 4
# Cbc0038I Pass   3: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass   4: suminf.    1.78738 (9) obj. 2.70009 iterations 8
# Cbc0038I Pass   5: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass   6: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass   7: suminf.    2.62489 (8) obj. 2.70009 iterations 2
# Cbc0038I Pass   8: suminf.    1.78738 (9) obj. 2.70009 iterations 2
# Cbc0038I Pass   9: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  10: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  11: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  12: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  13: suminf.    3.50000 (7) obj. 0 iterations 2
# Cbc0038I Pass  14: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  15: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  16: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  17: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  18: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  19: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  20: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  21: suminf.    3.50000 (7) obj. 2 iterations 4
# Cbc0038I Pass  22: suminf.    1.78738 (9) obj. 2.70009 iterations 5
# Cbc0038I Pass  23: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  24: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  25: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  26: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  27: suminf.    2.62489 (8) obj. 2.70009 iterations 3
# Cbc0038I Pass  28: suminf.    1.78738 (9) obj. 2.70009 iterations 3
# Cbc0038I Pass  29: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  31: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 4 - took 0.02 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# 0.03302407264709473
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 39 (-11) rows, 29 (-11) columns and 132 (-16) elements
# Clp0006I 0  Obj 0 Primal inf 48.796085 (15)
# Clp0000I Optimal - objective value 529.55941
# Coin0511I After Postsolve, objective 529.55941, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 529.5594076 - 12 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 40 rows, 29 columns (9 integer (9 of which binary)) and 127 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.526%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 3 integers unsatisfied sum - 0.754545
# Cbc0038I Pass   1: suminf.    0.57273 (3) obj. 644.88 iterations 11
# Cbc0038I Solution found of 819.046
# Cbc0038I Relaxing continuous gives 819.046
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 40 rows 29 columns, reduced to 7 rows 7 columns
# Cbc0038I Mini branch and bound improved solution from 819.046 to 622.063 (0.01 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 622.063
# Cbc0038I Round again with cutoff of 612.812
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.75455 (3) obj. 612.812 iterations 13
# Cbc0038I Pass   3: suminf.    0.09091 (1) obj. 612.812 iterations 8
# Cbc0038I Pass   4: suminf.    0.18182 (1) obj. 612.812 iterations 3
# Cbc0038I Pass   5: suminf.    0.55455 (2) obj. 612.812 iterations 5
# Cbc0038I Pass   6: suminf.    0.55455 (2) obj. 612.812 iterations 1
# Cbc0038I Pass   7: suminf.    0.48722 (1) obj. 612.812 iterations 6
# Cbc0038I Pass   8: suminf.    0.18182 (1) obj. 612.812 iterations 6
# Cbc0038I Pass   9: suminf.    0.55455 (2) obj. 612.812 iterations 2
# Cbc0038I Pass  10: suminf.    0.55455 (2) obj. 612.812 iterations 1
# Cbc0038I Pass  11: suminf.    0.75455 (3) obj. 612.812 iterations 2
# Cbc0038I Pass  12: suminf.    0.75455 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  13: suminf.    0.75455 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  14: suminf.    0.75455 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  15: suminf.    0.70864 (3) obj. 612.812 iterations 3
# Cbc0038I Pass  16: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  17: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  18: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  19: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  20: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  21: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  22: suminf.    0.70864 (3) obj. 612.812 iterations 0
# Cbc0038I Pass  23: suminf.    0.72312 (3) obj. 612.812 iterations 1
# Cbc0038I Pass  24: suminf.    0.36222 (1) obj. 612.812 iterations 5
# Cbc0038I Pass  25: suminf.    0.18182 (1) obj. 612.812 iterations 5
# Cbc0038I Pass  26: suminf.    0.38182 (2) obj. 612.812 iterations 4
# Cbc0038I Pass  27: suminf.    0.21591 (1) obj. 612.812 iterations 6
# Cbc0038I Pass  28: suminf.    0.18182 (1) obj. 612.812 iterations 5
# Cbc0038I Pass  29: suminf.    0.38182 (2) obj. 612.812 iterations 4
# Cbc0038I Pass  30: suminf.    0.09091 (1) obj. 612.812 iterations 6
# Cbc0038I Pass  31: suminf.    0.18182 (1) obj. 612.812 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 9 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 622.063 - took 0.02 seconds
# Cbc0012I Integer solution of 622.0626 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 40 rows 29 columns, reduced to 40 rows 23 columns
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 10 cuts changed objective from 529.55941 to 622.0626 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 2 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 5 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 622.0626028390617, took 0 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# 0.0463719367980957
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 14 (-16) rows, 11 (-15) columns and 40 (-38) elements
# Clp1000I sum of infeasibilities 0 - average 0, 11 fixed columns
# Coin0506I Presolve 0 (-14) rows, 0 (-11) columns and 0 (-40) elements
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 14 rows, 11 columns (11 integer (10 of which binary)) and 40 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 3.953%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -0
# Cbc0038I Cleaned solution of -0
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -0 - took 0.00 seconds
# Cbc0012I Integer solution of -0 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -0, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 0.009570837020874023
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 14 (-16) rows, 11 (-15) columns and 40 (-38) elements
# Clp1000I sum of infeasibilities 0 - average 0, 11 fixed columns
# Coin0506I Presolve 0 (-14) rows, 0 (-11) columns and 0 (-40) elements
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 14 rows, 11 columns (11 integer (10 of which binary)) and 40 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 3.953%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -0
# Cbc0038I Cleaned solution of -0
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -0 - took 0.00 seconds
# 0.010537385940551758
# Cbc0012I Integer solution of -0 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -0, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 35 (-6) rows, 24 (-10) columns and 106 (-14) elements
# Clp0006I 0  Obj 0 Primal inf 46.667993 (11)
# Clp0000I Optimal - objective value 556.16085
# Coin0511I After Postsolve, objective 556.16085, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 556.1608534 - 17 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 35 rows, 24 columns (8 integer (8 of which binary)) and 106 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.680%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 4 integers unsatisfied sum - 0.677778
# Cbc0038I Pass   1: suminf.    0.67778 (3) obj. 563.699 iterations 7
# Cbc0038I Solution found of 656.456
# Cbc0038I Relaxing continuous gives 656.456
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 5 continuous
# Cbc0038I Full problem 35 rows 24 columns, reduced to 12 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 646.427
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.67778 (3) obj. 563.699 iterations 0
# Cbc0038I Pass   3: suminf.    0.05195 (2) obj. 646.427 iterations 9
# Cbc0038I Pass   4: suminf.    0.22222 (1) obj. 619.633 iterations 4
# Cbc0038I Pass   5: suminf.    0.45803 (1) obj. 646.427 iterations 3
# Cbc0038I Pass   6: suminf.    0.45803 (1) obj. 646.427 iterations 0
# Cbc0038I Pass   7: suminf.    0.27483 (1) obj. 646.427 iterations 2
# Cbc0038I Pass   8: suminf.    0.22222 (1) obj. 604.282 iterations 4
# Cbc0038I Pass   9: suminf.    0.27483 (1) obj. 646.427 iterations 4
# Cbc0038I Pass  10: suminf.    0.45803 (1) obj. 646.427 iterations 2
# Cbc0038I Pass  11: suminf.    0.66810 (2) obj. 646.427 iterations 2
# Cbc0038I Pass  12: suminf.    0.65772 (3) obj. 646.427 iterations 2
# Cbc0038I Pass  13: suminf.    0.65772 (3) obj. 646.427 iterations 0
# Cbc0038I Pass  14: suminf.    0.45803 (1) obj. 646.427 iterations 3
# Cbc0038I Pass  15: suminf.    0.22222 (1) obj. 619.633 iterations 3
# Cbc0038I Pass  16: suminf.    0.46430 (2) obj. 646.427 iterations 3
# Cbc0038I Pass  17: suminf.    0.46430 (2) obj. 646.427 iterations 0
# Cbc0038I Pass  18: suminf.    0.46430 (2) obj. 646.427 iterations 0
# Cbc0038I Pass  19: suminf.    0.46430 (2) obj. 646.427 iterations 0
# Cbc0038I Pass  20: suminf.    0.65772 (3) obj. 646.427 iterations 1
# Cbc0038I Pass  21: suminf.    0.46430 (2) obj. 646.427 iterations 1
# Cbc0038I Pass  22: suminf.    0.65772 (3) obj. 646.427 iterations 1
# Cbc0038I Pass  23: suminf.    0.75499 (4) obj. 646.427 iterations 6
# Cbc0038I Pass  24: suminf.    0.44444 (2) obj. 646.427 iterations 8
# Cbc0038I Pass  25: suminf.    0.05195 (2) obj. 646.427 iterations 8
# Cbc0038I Pass  26: suminf.    0.22222 (1) obj. 619.633 iterations 6
# Cbc0038I Pass  27: suminf.    0.45803 (1) obj. 646.427 iterations 4
# Cbc0038I Pass  28: suminf.    0.45803 (1) obj. 646.427 iterations 0
# Cbc0038I Pass  29: suminf.    0.66810 (2) obj. 646.427 iterations 2
# Cbc0038I Pass  30: suminf.    0.66810 (2) obj. 646.427 iterations 0
# Cbc0038I Pass  31: suminf.    0.66810 (2) obj. 646.427 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 5 continuous
# Cbc0038I Full problem 35 rows 24 columns, reduced to 12 rows 11 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of 656.456 - took 0.02 seconds
# Cbc0012I Integer solution of 656.45628 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 35 rows 24 columns, reduced to 31 rows 19 columns
# Cbc0031I 5 added rows had average density of 5
# Cbc0013I At root node, 6 cuts changed objective from 556.16085 to 656.45628 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 5 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 5 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 656.4562754102677, took 5 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# 0.039443254470825195
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 32 (-24) rows, 22 (-14) columns and 96 (-56) elements
# Clp1000I sum of infeasibilities 2.37936e-08 - average 7.43551e-10, 14 fixed columns
# Coin0506I Presolve 18 (-14) rows, 8 (-14) columns and 40 (-56) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 32 rows, 22 columns (22 integer (22 of which binary)) and 96 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.222%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 0 - took 0.00 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 0.007993698120117188
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 32 (-24) rows, 22 (-14) columns and 96 (-56) elements
# Clp1000I sum of infeasibilities 2.37936e-08 - average 7.43551e-10, 14 fixed columns
# Coin0506I Presolve 18 (-14) rows, 8 (-14) columns and 40 (-56) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 8 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 32 rows, 22 columns (22 integer (22 of which binary)) and 96 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.222%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 0 - took 0.00 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 0.010982036590576172
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 40 (-6) rows, 29 (-9) columns and 127 (-9) elements
# Clp0006I 0  Obj 0 Primal inf 33.314205 (12)
# Clp0000I Optimal - objective value 360.14182
# Coin0511I After Postsolve, objective 360.14182, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 360.1418155 - 13 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 40 rows, 29 columns (9 integer (9 of which binary)) and 127 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.526%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.444444
# Cbc0038I Pass   1: suminf.    0.44444 (2) obj. 559.044 iterations 3
# Cbc0038I Solution found of 695.699
# Cbc0038I Relaxing continuous gives 695.699
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 10 continuous
# Cbc0038I Full problem 40 rows 29 columns, reduced to 12 rows 9 columns
# Cbc0038I Mini branch and bound improved solution from 695.699 to 430.638 (0.01 seconds)
# Cbc0038I Round again with cutoff of 423.588
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.44444 (3) obj. 423.588 iterations 2
# Cbc0038I Pass   3: suminf.    0.49913 (1) obj. 423.588 iterations 4
# Cbc0038I Pass   4: suminf.    0.22222 (1) obj. 423.588 iterations 2
# Cbc0038I Pass   5: suminf.    0.22222 (1) obj. 423.588 iterations 6
# Cbc0038I Pass   6: suminf.    0.49913 (1) obj. 423.588 iterations 2
# Cbc0038I Pass   7: suminf.    0.22222 (1) obj. 423.588 iterations 2
# Cbc0038I Pass   8: suminf.    0.44444 (3) obj. 423.588 iterations 3
# Cbc0038I Pass   9: suminf.    0.56585 (2) obj. 423.588 iterations 2
# Cbc0038I Pass  10: suminf.    0.56585 (2) obj. 423.588 iterations 0
# Cbc0038I Pass  11: suminf.    0.56585 (2) obj. 423.588 iterations 0
# Cbc0038I Pass  12: suminf.    0.75926 (3) obj. 423.588 iterations 1
# Cbc0038I Pass  13: suminf.    0.75926 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  14: suminf.    0.75926 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  15: suminf.    0.40855 (2) obj. 423.588 iterations 3
# Cbc0038I Pass  16: suminf.    0.49913 (1) obj. 423.588 iterations 2
# Cbc0038I Pass  17: suminf.    0.22222 (1) obj. 423.588 iterations 1
# Cbc0038I Pass  18: suminf.    0.22222 (1) obj. 423.588 iterations 0
# Cbc0038I Pass  19: suminf.    0.56585 (2) obj. 423.588 iterations 2
# Cbc0038I Pass  20: suminf.    0.49913 (1) obj. 423.588 iterations 1
# Cbc0038I Pass  21: suminf.    0.22222 (1) obj. 423.588 iterations 2
# Cbc0038I Pass  22: suminf.    0.44444 (3) obj. 423.588 iterations 4
# Cbc0038I Pass  23: suminf.    0.44444 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  24: suminf.    0.44444 (3) obj. 423.588 iterations 1
# Cbc0038I Pass  25: suminf.    0.56585 (2) obj. 423.588 iterations 2
# Cbc0038I Pass  26: suminf.    0.56585 (2) obj. 423.588 iterations 0
# Cbc0038I Pass  27: suminf.    0.75926 (3) obj. 423.588 iterations 1
# Cbc0038I Pass  28: suminf.    0.75926 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  29: suminf.    0.75926 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  30: suminf.    0.75926 (3) obj. 423.588 iterations 0
# Cbc0038I Pass  31: suminf.    0.40855 (2) obj. 423.588 iterations 3
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 40 rows 29 columns, reduced to 6 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of 410.899
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 3
# Cbc0038I Pass  31: suminf.    0.44444 (3) obj. 410.899 iterations 0
# Cbc0038I Pass  32: suminf.    0.35694 (1) obj. 410.899 iterations 4
# Cbc0038I Pass  33: suminf.    0.22222 (1) obj. 410.899 iterations 2
# Cbc0038I Pass  34: suminf.    0.54156 (2) obj. 410.899 iterations 4
# Cbc0038I Pass  35: suminf.    0.22222 (1) obj. 410.899 iterations 7
# Cbc0038I Pass  36: suminf.    0.35694 (1) obj. 410.899 iterations 2
# Cbc0038I Pass  37: suminf.    0.35694 (1) obj. 410.899 iterations 0
# Cbc0038I Pass  38: suminf.    0.44444 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  39: suminf.    0.54156 (2) obj. 410.899 iterations 2
# Cbc0038I Pass  40: suminf.    0.79259 (3) obj. 410.899 iterations 4
# Cbc0038I Pass  41: suminf.    0.44444 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  42: suminf.    0.44444 (3) obj. 410.899 iterations 0
# Cbc0038I Pass  43: suminf.    0.79259 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  44: suminf.    0.44444 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  45: suminf.    0.44444 (3) obj. 410.899 iterations 1
# Cbc0038I Pass  46: suminf.    0.35694 (1) obj. 410.899 iterations 4
# Cbc0038I Pass  47: suminf.    0.22222 (1) obj. 410.899 iterations 2
# Cbc0038I Pass  48: suminf.    0.44444 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  49: suminf.    0.79259 (3) obj. 410.899 iterations 3
# Cbc0038I Pass  50: suminf.    0.54156 (2) obj. 410.899 iterations 1
# Cbc0038I Pass  51: suminf.    0.22222 (1) obj. 410.899 iterations 6
# Cbc0038I Pass  52: suminf.    0.35694 (1) obj. 410.899 iterations 3
# Cbc0038I Pass  53: suminf.    0.43125 (2) obj. 410.899 iterations 2
# Cbc0038I Pass  54: suminf.    0.22222 (1) obj. 410.899 iterations 4
# Cbc0038I Pass  55: suminf.    0.22118 (1) obj. 410.899 iterations 3
# Cbc0038I Pass  56: suminf.    0.35694 (1) obj. 410.899 iterations 1
# Cbc0038I Pass  57: suminf.    0.22222 (1) obj. 410.899 iterations 2
# Cbc0038I Pass  58: suminf.    0.35694 (1) obj. 410.899 iterations 2
# Cbc0038I Pass  59: suminf.    0.79259 (3) obj. 410.899 iterations 2
# Cbc0038I Pass  60: suminf.    0.44444 (3) obj. 410.899 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 11 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of 430.638 - took 0.03 seconds
# Cbc0012I Integer solution of 430.63817 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0038I Full problem 40 rows 29 columns, reduced to 36 rows 20 columns
# Cbc0031I 2 added rows had average density of 5
# Cbc0013I At root node, 6 cuts changed objective from 360.14182 to 430.63817 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# ...
# Cbc0038I Pass  28: suminf.    1.78738 (9) obj. 2.70009 iterations 3
# Cbc0038I Pass  29: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  31: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 0.016590118408203125
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 32 (-24) rows, 21 (-21) columns and 96 (-56) elements
# Clp1000I sum of infeasibilities 1.69975e-08 - average 5.31172e-10, 14 fixed columns
# Coin0506I Presolve 18 (-14) rows, 7 (-14) columns and 40 (-56) elements
# Clp0006I 0  Obj 0
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Clp0000I Optimal - objective value 0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 0 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 32 rows, 21 columns (21 integer (21 of which binary)) and 96 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 2.326%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 7 integers unsatisfied sum - 3.5
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4 iterations 9
# Cbc0038I Solution found of 4
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of 2.70009
# Cbc0038I Reduced cost fixing fixed 12 variables on major pass 2
# Cbc0038I Pass   2: suminf.    1.78738 (9) obj. 2.70009 iterations 4
# Cbc0038I Pass   3: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass   4: suminf.    1.78738 (9) obj. 2.70009 iterations 8
# Cbc0038I Pass   5: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass   6: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass   7: suminf.    2.62489 (8) obj. 2.70009 iterations 2
# Cbc0038I Pass   8: suminf.    1.78738 (9) obj. 2.70009 iterations 2
# Cbc0038I Pass   9: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  10: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  11: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  12: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  13: suminf.    3.50000 (7) obj. 0 iterations 2
# Cbc0038I Pass  14: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  15: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  16: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  17: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  18: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  19: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  20: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  21: suminf.    3.50000 (7) obj. 2 iterations 4
# Cbc0038I Pass  22: suminf.    1.78738 (9) obj. 2.70009 iterations 5
# Cbc0038I Pass  23: suminf.    1.78738 (9) obj. 2.70009 iterations 1
# Cbc0038I Pass  24: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  25: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  26: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  27: suminf.    2.62489 (8) obj. 2.70009 iterations 3
# Cbc0038I Pass  28: suminf.    1.78738 (9) obj. 2.70009 iterations 3
# Cbc0038I Pass  29: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I Pass  30: suminf.    1.78738 (9) obj. 2.70009 iterations 9
# Cbc0038I Pass  31: suminf.    1.78738 (9) obj. 2.70009 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4 - took 0.01 seconds
# Cbc0012I Integer solution of 4 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 32 rows 21 columns, reduced to 16 rows 8 columns
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 12 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 0.01679682731628418
# Starting solution of the Linear programming relaxation problem using Dual Simplex
#
# Coin0506I Presolve 40 (-6) rows, 28 (-10) columns and 123 (-13) elements
# Clp0006I 0  Obj 0 Primal inf 63.299554 (14)
# Clp0000I Optimal - objective value 528.76948
# Coin0511I After Postsolve, objective 528.76948, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 528.769481 - 13 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 40 rows, 28 columns (9 integer (9 of which binary)) and 123 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.564%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0038I Initial state - 3 integers unsatisfied sum - 0.754545
# Cbc0038I Pass   1: suminf.    0.57273 (3) obj. 643.577 iterations 3
# Cbc0038I Solution found of 811.903
# Cbc0038I Relaxing continuous gives 811.903
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 10 continuous
# Cbc0038I Full problem 40 rows 28 columns, reduced to 7 rows 7 columns
# Cbc0038I Mini branch and bound improved solution from 811.903 to 618.171 (0.00 seconds)
# Cbc0038I Round again with cutoff of 609.231
# Cbc0038I Reduced cost fixing fixed 5 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.75455 (3) obj. 609.231 iterations 5
# Cbc0038I Pass   3: suminf.    0.09091 (1) obj. 609.231 iterations 4
# Cbc0038I Pass   4: suminf.    0.18182 (1) obj. 609.231 iterations 1
# Cbc0038I Pass   5: suminf.    0.18182 (1) obj. 609.231 iterations 1
# Cbc0038I Pass   6: suminf.    0.48721 (1) obj. 609.231 iterations 1
# Cbc0038I Pass   7: suminf.    0.18182 (1) obj. 609.231 iterations 1
# Cbc0038I Pass   8: suminf.    0.55455 (2) obj. 609.231 iterations 1
# Cbc0038I Pass   9: suminf.    0.55455 (2) obj. 609.231 iterations 1
# Cbc0038I Pass  10: suminf.    0.55455 (2) obj. 609.231 iterations 1
# Cbc0038I Pass  11: suminf.    0.55455 (2) obj. 609.231 iterations 0
# Cbc0038I Pass  12: suminf.    0.55455 (2) obj. 609.231 iterations 0
# Cbc0038I Pass  13: suminf.    0.71018 (3) obj. 609.231 iterations 2
# Cbc0038I Pass  14: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  15: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  16: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  17: suminf.    0.75455 (3) obj. 609.231 iterations 3
# Cbc0038I Pass  18: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  19: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  20: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  21: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  22: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  23: suminf.    0.75455 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  24: suminf.    0.71018 (3) obj. 609.231 iterations 3
# Cbc0038I Pass  25: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  26: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  27: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  28: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  29: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  30: suminf.    0.71018 (3) obj. 609.231 iterations 0
# Cbc0038I Pass  31: suminf.    0.75455 (3) obj. 609.231 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 8 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 618.171 - took 0.01 seconds
# Cbc0012I Integer solution of 618.17112 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 40 rows 28 columns, reduced to 40 rows 22 columns
# Cbc0031I 3 added rows had average density of 4
# Cbc0013I At root node, 10 cuts changed objective from 528.76948 to 618.17112 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 2 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 5 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 618.1711242303969, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 5 variables fixed on reduced cost
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# 0.01666712760925293
#
# 📊 ORIGINAL DATASET METRICS:
# original_crossings: 2
# original_crossing_score: 8.0
# original_vertical_score: 86.35
# original_total_width: 29
#
# 📊 Final Ranked Summary:
#     trial  final_score  original_score  total_crossing_score  \
# 0       4     0.000000       52.516667                   0.0
# 1      60     0.000000       52.516667                   0.0
# 2      43     0.000000       52.516667                   0.0
# 3      33     0.000000       52.516667                   0.0
# 4      51     0.000000       52.516667                   0.0
# ..    ...          ...             ...                   ...
# 95     93     1.829021       98.700000                   4.0
# 96    100     1.829021       98.700000                   4.0
# 97     37     1.908614      102.750000                   4.0
# 98     68     1.908614      102.750000                   4.0
# 99     73     1.924992      103.583333                   4.0
#
#     total_vertical_score  crossing_count  width_removed  width_removed_pct  \
# 0              52.516667               0              8              27.59
# 1              52.516667               0              8              27.59
# 2              52.516667               0              8              27.59
# 3              52.516667               0              8              27.59
# 4              52.516667               0              8              27.59
# ..                   ...             ...            ...                ...
# 95             94.700000               1              9              31.03
# 96             94.700000               1              9              31.03
# 97             98.750000               1              9              31.03
# 98             98.750000               1              9              31.03
# 99             99.583333               1              8              27.59
#
#    flows_removed
# 0   [4, 3, 6, 0]
# 1   [3, 4, 0, 6]
# 2   [3, 4, 0, 6]
# 3   [3, 4, 6, 0]
# 4   [3, 4, 0, 6]
# ..           ...
# 95     [5, 8, 6]
# 96     [5, 8, 6]
# 97        [7, 5]
# 98        [7, 5]
# 99        [2, 8]
#
# [100 rows x 9 columns]
#
# 📄 Top 3 Layouts Summary (Row Format):
# Trial 4 | Crossings: 0 | Area: 0.0 | Span: 52.516666666666666 | Width: 29 | Removed: 8 (27.59%) | Flows: [4, 3, 6, 0]
# Trial 60 | Crossings: 0 | Area: 0.0 | Span: 52.516666666666666 | Width: 29 | Removed: 8 (27.59%) | Flows: [3, 4, 0, 6]
# Trial 43 | Crossings: 0 | Area: 0.0 | Span: 52.516666666666666 | Width: 29 | Removed: 8 (27.59%) | Flows: [3, 4, 0, 6]

# %%
# --- Step 1: Manually specify rows to hide ---

rows_to_hide =   [1, 0, 3, 13, 9]
# --- Step 2: Hide flows in dataset ---
def hide_flows_by_index(dataset, row_indices):
    flows = dataset._flows.copy()
    rows = flows.iloc[row_indices]

    hidden = []
    for _, row in rows.iterrows():
        r1, r2 = row.copy(), row.copy()
        r1["source"] = "HIDDEN"
        r2["target"] = "HIDDEN"
        hidden.extend([r1, r2])
    
    new_flows = pd.concat([
        flows.drop(index=row_indices),
        pd.DataFrame(hidden)
    ], ignore_index=True)
    
    print(flows)

    return Dataset(new_flows, dataset._dim_process, dataset._dim_material)

# --- Step 3: Build new dataset with hidden flows ---
sdd = SankeyDefinition(nodes, bundles, ordering,flow_partition=dataset.partition('material'))
updated_dataset = hide_flows_by_index(dataset, rows_to_hide)

# --- Step 4: Create Sankey layout ---
sankey_data = weave(sdd, updated_dataset,palette=palette)
sankey_data_manual_evolve = optimise_node_order(sankey_data, group_nodes=True)

#sankey_data_manual_evolve.to_widget(layout=optimise_node_positions(sankey_data_manual_evolve, scale = 10,minimum_gap=20, margins=dict(left=100, right=120)), width=700, height=450)   
sankey_data_manual_evolve.to_widget(layout=optimise_node_positions(sankey_data_manual_evolve, scale = 7,minimum_gap=10, margins=dict(left=50, right=220)), width=1000, height=800)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/indexing.py:1714, in _iLocIndexer._get_list_axis(self, key, axis)
#    1713 try:
# -> 1714     return self.obj._take_with_is_copy(key, axis=axis)
#    1715 except IndexError as err:
#    1716     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4144 """
#    4145 Internal version of the `take` method that sets the `_is_copy`
#    4146 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151 See the docstring of `take` for full explanation of the parameters.
#    4152 """
# -> 4153 result = self.take(indices=indices, axis=axis)
#    4154 # Maybe set copy if we didn't actually change the index.
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/internals/managers.py:891, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 n = self.shape[axis]
# --> 891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/indexers/utils.py:282, in maybe_convert_indices(indices, n, verify)
#     281     if mask.any():
# --> 282         raise IndexError("indices are out-of-bounds")
#     283 return indices
#
# IndexError: indices are out-of-bounds
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 27
#      25 # --- Step 3: Build new dataset with hidden flows ---
#      26 sdd = SankeyDefinition(nodes, bundles, ordering,flow_partition=dataset.partition('material'))
# ---> 27 updated_dataset = hide_flows_by_index(dataset, rows_to_hide)
#      29 # --- Step 4: Create Sankey layout ---
#      30 sankey_data = weave(sdd, updated_dataset,palette=palette)
#
# Cell In[47], line 7, in hide_flows_by_index(dataset, row_indices)
#       5 def hide_flows_by_index(dataset, row_indices):
#       6     flows = dataset._flows.copy()
# ----> 7     rows = flows.iloc[row_indices]
#       9     hidden = []
#      10     for _, row in rows.iterrows():
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/indexing.py:1743, in _iLocIndexer._getitem_axis(self, key, axis)
#    1741 # a list of integers
#    1742 elif is_list_like_indexer(key):
# -> 1743     return self._get_list_axis(key, axis=axis)
#    1745 # a single integer
#    1746 else:
#    1747     key = item_from_zerodim(key)
#
# File /opt/anaconda3/envs/floweaver_env/lib/python3.9/site-packages/pandas/core/indexing.py:1717, in _iLocIndexer._get_list_axis(self, key, axis)
#    1714     return self.obj._take_with_is_copy(key, axis=axis)
#    1715 except IndexError as err:
#    1716     # re-raise with different error message, e.g. test_getitem_ndarray_3d
# -> 1717     raise IndexError("positional indexers are out-of-bounds") from err
#
# IndexError: positional indexers are out-of-bounds
